# %% [markdown]
# ### Stock Prediction Machine Learning Model Notebook

# %% [markdown]
# ## Phase 1 : Importing Necessary Libraries + Importing Data + Data Preperation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df_TCS = pd.read_csv(r"Data\CUPID\CUPID.NS_data.csv")

# %%
df_TCS.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2339 entries, 0 to 2338
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2339 non-null   str
#  1   Close   2338 non-null   str
#  2   High    2338 non-null   str
#  3   Low     2338 non-null   str
#  4   Open    2338 non-null   str
#  5   Volume  2338 non-null   str
# dtypes: str(6)
# memory usage: 109.8 KB

# %%
df_TCS.head()
# Out:
#         Price               Close                High                Low  \
# 0      Ticker            CUPID.NS            CUPID.NS           CUPID.NS
# 1        Date                 NaN                 NaN                NaN
# 2  2016-09-16   2.239258289337158   2.534146754066101  2.186236899677606
# 3  2016-09-19  2.3024487495422363   2.336586446745387  2.251606378795482
# 4  2016-09-20  2.3144330978393555  2.3376756739979134  2.289012328909346
#
#                  Open    Volume
# 0            CUPID.NS  CUPID.NS
# 1                 NaN       NaN
# 2  2.4041342968512707  27578520
# 3   2.284290908420661   6128160
# 4    2.29627525731566   3301320

# %%
df_TCS.describe()
# Out:
#          Price               Close  High                 Low  \
# count     2339                2338  2338                2338
# unique    2339                2193  2289                2270
# top     Ticker  1.1795645952224731  18.0  16.799999237060547
# freq         1                   3     4                   5
#
#                       Open   Volume
# count                 2338     2338
# unique                2274     2324
# top     16.200000762939453  5071680
# freq                     4        2

# %%
df_TCS = df_TCS.rename(columns={'Price':'Date'})

# %%
df_TCS = df_TCS.iloc[2:].reset_index(drop=True)

# %% [markdown]
# #### Changing type of Data to Decimal and Numeric

# %%
df_TCS['Date'] = pd.to_datetime(df_TCS['Date'])

decimal_values = ["Close", "High", "Low", "Open"]
numeric_values =["Volume"]

for i in decimal_values:
    df_TCS[i] = df_TCS[i].astype(float)

for j in numeric_values:
    df_TCS[j] = pd.to_numeric(df_TCS[j])

# %%
# Sorting Values By Date

df_TCS = df_TCS.sort_values(by="Date").reset_index(drop=True)

# %% [markdown]
# # Volume Ratio over a 20 days window

# %%
df_TCS['Volume_Ratio'] = df_TCS['Volume'] / df_TCS['Volume'].rolling(window=20).mean()

# %%
df_TCS.corr()
# Out:
#                   Date     Close      High       Low      Open    Volume  \
# Date          1.000000  0.602915  0.601917  0.603861  0.602664  0.188018
# Close         0.602915  1.000000  0.999384  0.999578  0.998926  0.272971
# High          0.601917  0.999384  1.000000  0.999001  0.999473  0.280529
# Low           0.603861  0.999578  0.999001  1.000000  0.999323  0.261483
# Open          0.602664  0.998926  0.999473  0.999323  1.000000  0.266217
# Volume        0.188018  0.272971  0.280529  0.261483  0.266217  1.000000
# Volume_Ratio -0.001669 -0.003944 -0.000715 -0.010416 -0.008827  0.586642
#
#               Volume_Ratio
# Date             -0.001669
# Close            -0.003944
# High             -0.000715
# Low              -0.010416
# Open             -0.008827
# Volume            0.586642
# Volume_Ratio      1.000000

# %% [markdown]
# #### Calculating Returns on Stock Price

# %%
df_TCS['Daily_Returns'] = df_TCS['Close'].pct_change()

# %% [markdown]
# ### Calculating Moving Averages Across the Range

# %%
df_TCS['MA_Week'] = df_TCS['Close'].rolling(window=7).mean()

df_TCS['MA_Month'] = df_TCS['Close'].rolling(window=30).mean()

df_TCS['MA_3Months'] = df_TCS['Close'].rolling(window=90).mean()

# %%
df_TCS.corr()
# Out:
#                    Date     Close      High       Low      Open    Volume  \
# Date           1.000000  0.602915  0.601917  0.603861  0.602664  0.188018
# Close          0.602915  1.000000  0.999384  0.999578  0.998926  0.272971
# High           0.601917  0.999384  1.000000  0.999001  0.999473  0.280529
# Low            0.603861  0.999578  0.999001  1.000000  0.999323  0.261483
# Open           0.602664  0.998926  0.999473  0.999323  1.000000  0.266217
# Volume         0.188018  0.272971  0.280529  0.261483  0.266217  1.000000
# Volume_Ratio  -0.001669 -0.003944 -0.000715 -0.010416 -0.008827  0.586642
# Daily_Returns  0.062402  0.054227  0.045215  0.046369  0.036966  0.300983
# MA_Week        0.603256  0.998025  0.998806  0.997661  0.998125  0.281415
# MA_Month       0.606108  0.990287  0.991547  0.990257  0.990996  0.274868
# MA_3Months     0.638358  0.972617  0.973399  0.973499  0.973639  0.239514
#
#                Volume_Ratio  Daily_Returns   MA_Week  MA_Month  MA_3Months
# Date              -0.001669       0.062402  0.603256  0.606108    0.638358
# Close             -0.003944       0.054227  0.998025  0.990287    0.972617
# High              -0.000715       0.045215  0.998806  0.991547    0.973399
# Low               -0.010416       0.046369  0.997661  0.990257    0.973499
# Open              -0.008827       0.036966  0.998125  0.990996    0.973639
# Volume             0.586642       0.300983  0.281415  0.274868    0.239514
# Volume_Ratio       1.000000       0.405213 -0.004901 -0.008676   -0.013375
# Daily_Returns      0.405213       1.000000  0.035183  0.031600    0.023868
# MA_Week           -0.004901       0.035183  1.000000  0.994073    0.977093
# MA_Month          -0.008676       0.031600  0.994073  1.000000    0.989407
# MA_3Months        -0.013375       0.023868  0.977093  0.989407    1.000000

# %% [markdown]
# ### The correlation of Above features is very high so we must avoid them and we are using their ratios

# %%
df_TCS['MA_Week_Ratio'] = df_TCS['Close'] / df_TCS['MA_Week']
df_TCS['MA_Month_Ratio'] = df_TCS['Close'] / df_TCS['MA_Month']
df_TCS['MA_3Months_Ratio'] = df_TCS['Close'] / df_TCS['MA_3Months']

# %%
df_TCS.corr()
# Out:
#                       Date     Close      High       Low      Open    Volume  \
# Date              1.000000  0.602915  0.601917  0.603861  0.602664  0.188018
# Close             0.602915  1.000000  0.999384  0.999578  0.998926  0.272971
# High              0.601917  0.999384  1.000000  0.999001  0.999473  0.280529
# Low               0.603861  0.999578  0.999001  1.000000  0.999323  0.261483
# Open              0.602664  0.998926  0.999473  0.999323  1.000000  0.266217
# Volume            0.188018  0.272971  0.280529  0.261483  0.266217  1.000000
# Volume_Ratio     -0.001669 -0.003944 -0.000715 -0.010416 -0.008827  0.586642
# Daily_Returns     0.062402  0.054227  0.045215  0.046369  0.036966  0.300983
# MA_Week           0.603256  0.998025  0.998806  0.997661  0.998125  0.281415
# MA_Month          0.606108  0.990287  0.991547  0.990257  0.990996  0.274868
# MA_3Months        0.638358  0.972617  0.973399  0.973499  0.973639  0.239514
# MA_Week_Ratio     0.137918  0.120328  0.112640  0.117137  0.111054  0.297749
# MA_Month_Ratio    0.279065  0.261076  0.256402  0.258435  0.255169  0.347924
# MA_3Months_Ratio  0.407101  0.448570  0.445802  0.446024  0.444397  0.335483
#
#                   Volume_Ratio  Daily_Returns   MA_Week  MA_Month  MA_3Months  \
# Date                 -0.001669       0.062402  0.603256  0.606108    0.638358
# Close                -0.003944       0.054227  0.998025  0.990287    0.972617
# High                 -0.000715       0.045215  0.998806  0.991547    0.973399
# Low                  -0.010416       0.046369  0.997661  0.990257    0.973499
# Open                 -0.008827       0.036966  0.998125  0.990996    0.973639
# Volume                0.586642       0.300983  0.281415  0.274868    0.239514
# Volume_Ratio          1.000000       0.405213 -0.004901 -0.008676   -0.013375
# Daily_Returns         0.405213       1.000000  0.035183  0.031600    0.023868
# MA_Week              -0.004901       0.035183  1.000000  0.994073    0.977093
# MA_Month             -0.008676       0.031600  0.994073  1.000000    0.989407
# MA_3Months           -0.013375       0.023868  0.977093  0.989407    1.000000
# MA_Week_Ratio         0.372260       0.636327  0.088670  0.070847    0.055137
# MA_Month_Ratio        0.191611       0.323946  0.239318  0.184563    0.141327
# MA_3Months_Ratio      0.059141       0.210526  0.433606  0.385610    0.314425
#
#                   MA_Week_Ratio  MA_Month_Ratio  MA_3Months_Ratio
# Date                   0.137918        0.279065          0.407101
# Close                  0.120328        0.261076          0.448570
# High                   0.112640        0.256402          0.445802
# Low                    0.117137        0.258435          0.446024
# Open                   0.111054        0.255169          0.444397
# Volume                 0.297749        0.347924          0.335483
# Volume_Ratio           0.372260        0.191611          0.059141
# Daily_Returns          0.636327        0.323946          0.210526
# MA_Week                0.088670        0.239318          0.433606
# MA_Month               0.070847        0.184563          0.385610
# MA_3Months             0.055137        0.141327          0.314425
# MA_Week_Ratio          1.000000        0.663847          0.446729
# MA_Month_Ratio         0.663847        1.000000          0.828826
# MA_3Months_Ratio       0.446729        0.828826          1.000000

# %% [markdown]
# ### MACD (Moving Average Convergence Divergence)

# %% [markdown]
# ##### Exponential Moving average

# %%
ema_12 = df_TCS['Close'].ewm(span=12, adjust=False).mean()
ema_26 = df_TCS['Close'].ewm(span=26, adjust=False).mean()

# %%
df_TCS['MACD'] = ema_12 - ema_26

# %%
df_TCS['MACD_Signal'] = df_TCS['MACD'].ewm(span=9, adjust=False).mean()

# %%
# Volatility to Measure the High Risk Periods
df_TCS['volatility'] = df_TCS['Daily_Returns'].rolling(window=20).std()

# %%
mean_volatility = df_TCS['volatility'].mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_TCS.index, df_TCS['volatility'], label='20-Day Rolling Volatility', color='red', linewidth=2)
plt.axhline(mean_volatility, color='green',linestyle='--', label='Mean Volatility')
plt.title('TCS Daily Returns and 20-Day Rolling Volatility')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

# %%
# Computing RSI (Relative Strength Index) , it measures speed and magnitude of Price Movements

# RSI compares (Average Gains VS Average Losses)

delta = df_TCS['Close'].diff()
gain = delta.clip(lower=0)
loss = -delta.clip(upper=0)

avg_gain = gain.ewm(span=14, adjust=False).mean()
avg_loss = loss.ewm(span=14, adjust=False).mean()

rs = avg_gain/avg_loss

df_TCS['RSI'] = 100-(100/(1+rs))

# %%
EMA_12 = df_TCS['Close'].ewm(span=12, adjust=False).mean()
EMA_26 = df_TCS['Close'].ewm(span=26, adjust=False).mean()
MACD_Line = EMA_12 - EMA_26
Signal_Line = MACD_Line.ewm(span=9, adjust=False).mean()
df_TCS['MACD_Histogram'] = MACD_Line - Signal_Line

# %% [markdown]
# ### Bollinger Band Indicator

# %%
BB_Middle = df_TCS['Close'].rolling(window=20).mean()
BB_Std = df_TCS['Close'].rolling(window=20).std()
BB_Upper = BB_Middle + (2 * BB_Std)
BB_Lower = BB_Middle - (2 * BB_Std)

df_TCS['BB_Position'] = (df_TCS['Close'] - BB_Middle) / (2 * BB_Std)

# %%
plt.figure(figsize=(12,6))

plt.plot(df_TCS['Date'], df_TCS['Close'], label='Close Price', color='blue')
plt.plot(df_TCS['Date'], BB_Middle, label='BB Middle (20-day SMA)', color='black')
plt.plot(df_TCS['Date'], BB_Upper, label='BB Upper', color='red')
plt.plot(df_TCS['Date'], BB_Lower, label='BB Lower', color='green')

plt.fill_between(df_TCS['Date'], BB_Upper, BB_Lower, color='lightgray', alpha=0.3)

plt.title('Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# #### Due to Size of Data Range, the visualization is not too much beneficial on a 10 year time period scale . So Visualizing through Interactive plot based on plotly

# %%
import plotly.graph_objects as go

fig = go.Figure()


fig.add_trace(go.Scatter(x=df_TCS['Date'], y=BB_Upper, name='Upper Band', line=dict(color='red', width=1)))
fig.add_trace(go.Scatter(x=df_TCS['Date'], y=BB_Lower, name='Lower Band', line=dict(color='green', width=1), fill='tonexty', fillcolor='rgba(128, 128, 128, 0.2)'))
fig.add_trace(go.Scatter(x=df_TCS['Date'], y=BB_Middle, name='Middle Band', line=dict(color='black', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=df_TCS['Date'], y=df_TCS['Close'], name='Close Price', line=dict(color='blue', width=2)))



fig.add_trace(go.Scatter(x=df_TCS['Date'], y=BB_Upper, name='Upper Band', line=dict(color='red', width=1)))
fig.add_trace(go.Scatter(x=df_TCS['Date'], y=BB_Lower, name='Lower Band', line=dict(color='green', width=1), fill='tonexty', fillcolor='rgba(128, 128, 128, 0.2)'))
fig.add_trace(go.Scatter(x=df_TCS['Date'], y=BB_Middle, name='Middle Band', line=dict(color='black', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=df_TCS['Date'], y=df_TCS['Close'], name='Close Price', line=dict(color='blue', width=2)))

# %%
'''

Bollinger Bands provide a powerful way for a machine learning model to predict this target 
by answering two critical questions:

Is the price "Overextended"? (Mean Reversion) If your BB_Position feature approaches or exceeds 1.0,
the stock is hitting the Upper Bollinger Band. In many market environments, 
this indicates the stock is overbought and due for a pullback. 
Therefore, a high BB_Position today should increase the probability that the model predicts a 
Target of 0 (Down) for tomorrow. Conversely, a BB_Position near -1.0 (touching the lower band) 
often precedes a bounce, increasing the probability of a Target of 1 (Up).

Is a Massive Move Coming? (Volatility Breakout) When the bands get very tight (low volatility), 
it often precedes an explosive move. While the bands themselves don't predict the direction of the 
breakout, when combined with other momentum indicators (like your MACD_Histogram or RSI), 
a tight band followed by a sudden widening can signal the start of a strong new trend, making the 
model highly confident in predicting a sequence of 1s or 0s.

'''
# Out:
# '\n\nBollinger Bands provide a powerful way for a machine learning model to predict this target \nby answering two critical questions:\n\nIs the price "Overextended"? (Mean Reversion) If your BB_Position feature approaches or exceeds 1.0,\nthe stock is hitting the Upper Bollinger Band. In many market environments, \nthis indicates the stock is overbought and due for a pullback. \nTherefore, a high BB_Position today should increase the probability that the model predicts a \nTarget of 0 (Down) for tomorrow. Conversely, a BB_Position near -1.0 (touching the lower band) \noften precedes a bounce, increasing the probability of a Target of 1 (Up).\n\nIs a Massive Move Coming? (Volatility Breakout) When the bands get very tight (low volatility), \nit often precedes an explosive move. While the bands themselves don\'t predict the direction of the \nbreakout, when combined with other momentum indicators (like your MACD_Histogram or RSI), \na tight band followed by a sudden widening can signal the start of a strong new trend, making the \nmodel highly confident in predicting a sequence of 1s or 0s.\n\n'

# %% [markdown]
# ### Average True Range

# %%
''' ATR measures the absolute size of a stock's daily price moves, 
factoring in "gaps" between trading days. '''
# Out:
# ' ATR measures the absolute size of a stock\'s daily price moves, \nfactoring in "gaps" between trading days. '

# %%
prev_close = df_TCS['Close'].shift(1)
tr1 = df_TCS['High'] - df_TCS['Low']
tr2 = (df_TCS['High'] - prev_close).abs()
tr3 = (df_TCS['Low'] - prev_close).abs()
true_range = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
df_TCS['ATR_Ratio'] = true_range.rolling(window=14).mean() / df_TCS['Close']

# %% [markdown]
# ### Creating Prediction Target

# %%
df_TCS['Next_Day_Return'] = df_TCS['Daily_Returns'].shift(-1)

threshold = 0
df_TCS['Target'] = np.nan
df_TCS.loc[df_TCS['Next_Day_Return'] > threshold, 'Target'] = 1
df_TCS.loc[df_TCS['Next_Day_Return'] < -threshold, 'Target'] = 0

# %%
df_TCS['Target'].isnull().sum()
# Out:
# np.int64(17)

# %% [markdown]
# #### Lag Features

# %%
# Lag Features
df_TCS['Return_Lag1'] = df_TCS['Daily_Returns'].shift(1)
df_TCS['Return_Lag2'] = df_TCS['Daily_Returns'].shift(2)
df_TCS['Return_Lag3'] = df_TCS['Daily_Returns'].shift(3)
df_TCS['RSI_Lag1'] = df_TCS['RSI'].shift(1)

# %%
df_TCS['Day_of_Week'] = df_TCS['Date'].dt.dayofweek

# %%
df_TCS = df_TCS.dropna()
df_TCS.isnull().sum()
# Out:
# Date                0
# Close               0
# High                0
# Low                 0
# Open                0
# Volume              0
# Volume_Ratio        0
# Daily_Returns       0
# MA_Week             0
# MA_Month            0
# MA_3Months          0
# MA_Week_Ratio       0
# MA_Month_Ratio      0
# MA_3Months_Ratio    0
# MACD                0
# MACD_Signal         0
# volatility          0
# RSI                 0
# MACD_Histogram      0
# BB_Position         0
# ATR_Ratio           0
# Next_Day_Return     0
# Target              0
# Return_Lag1         0
# Return_Lag2         0
# Return_Lag3         0
# RSI_Lag1            0
# Day_of_Week         0
# dtype: int64

# %%
plt.pie(df_TCS['Target'].value_counts().values, 
        labels=[0, 1], autopct='%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# Price Trend Over the Time
plt.figure(figsize=(10,6))
plt.plot(df_TCS['Date'], df_TCS['Close'], )
plt.title("Price Trend Visualization")
plt.xlabel("Date")
plt.ylabel("CLOSING PRICE")
plt.show()

# %%
# Volume trend Over Time
plt.figure(figsize=(10,6))
df_TCS.plot(x='Date', y='Volume', kind='line', title="Volume trend over Period")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
# The Line shows a Outlier in Volume . Check it using Box Plot
plt.figure(figsize=(10,6))
plt.boxplot(df_TCS["Volume"])
plt.title("Volume trend Over Period BoxPlot")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
# Visualization of the Returns
plt.figure(figsize=(10,6))
plt.hist(df_TCS['Daily_Returns'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel("Profits%")
plt.ylabel("Frequency")
plt.title("Returns Over the Period")
plt.grid(True) 
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(df_TCS['Date'], df_TCS['Close'], label='Close Price')
plt.plot(df_TCS['Date'], df_TCS['MA_Week'], label='Weekly Moving Average')
plt.plot(df_TCS['Date'], df_TCS['MA_Month'], label="Monthly Moving Average")
plt.title("Price Graph with Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
# CandleStick type of Chart
import mplfinance as mpf


# before that set the date column as index column
df_TCS = df_TCS.set_index('Date')
df_TCS = df_TCS.sort_index()

mpf.plot(df_TCS, type='candle', style='yahoo', title=f'Candlestick Chart', volume=True)
# Out:
# c:\Users\vishe\OneDrive\Desktop\SUL_PROJECT\.venv\Lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
# Plot Date VS Volatily
plt.figure(figsize=(10,6))
plt.plot(df_TCS.index,df_TCS['volatility'])
plt.title("Volatility of the Returns")
plt.xlabel("Date")
plt.ylabel("Returns")
plt.show()

# %%
# Check the Correlation between all the calculated values
corr_matrix = df_TCS.select_dtypes('number').corr()

plt.figure(figsize=(18,14))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Plot Histogram for Volume to check for trading activity 
df_TCS.plot(kind='hist', y='Volume', bins=20, title='Volume Distribution')
plt.xlabel("Volume")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,1,1)
plt.plot(df_TCS['Close'], label= "Stock Price")
plt.title("Stock Price")
plt.legend()

plt.subplot(2,1,2)
plt.plot(df_TCS['RSI'], label='RSI', color='purple')
plt.axhline(70, linestyle='--', color='red')  # threshold when stock is overbought
plt.axhline(30, linestyle='--', color='green') # threshold when stock is oversold

plt.title("Relative Strength INDEX (RSI)")

plt.legend()
plt.tight_layout()
plt.show()

# %%
df_TCS.corr()
# Out:
#                      Close      High       Low      Open    Volume  \
# Close             1.000000  0.999368  0.999579  0.998919  0.270249
# High              0.999368  1.000000  0.998982  0.999473  0.277939
# Low               0.999579  0.998982  1.000000  0.999308  0.258697
# Open              0.998919  0.999473  0.999308  1.000000  0.263525
# Volume            0.270249  0.277939  0.258697  0.263525  1.000000
# Volume_Ratio     -0.002331  0.000969 -0.008975 -0.007347  0.586696
# Daily_Returns     0.051441  0.042226  0.043595  0.034011  0.296433
# MA_Week           0.998003  0.998799  0.997601  0.998077  0.279135
# MA_Month          0.990080  0.991394  0.990039  0.990827  0.272078
# MA_3Months        0.972469  0.973288  0.973268  0.973438  0.238743
# MA_Week_Ratio     0.117392  0.109540  0.114298  0.108118  0.293716
# MA_Month_Ratio    0.260687  0.255858  0.257996  0.254597  0.346661
# MA_3Months_Ratio  0.449759  0.446881  0.447223  0.445499  0.334265
# MACD              0.711139  0.708269  0.708036  0.706676  0.247802
# MACD_Signal       0.750798  0.751139  0.746730  0.747668  0.304655
# volatility        0.137564  0.142379  0.134779  0.138876  0.318401
# RSI               0.234656  0.228755  0.231728  0.227129  0.317685
# MACD_Histogram   -0.053742 -0.067614 -0.050197 -0.060015 -0.198594
# BB_Position       0.155552  0.151371  0.152478  0.149174  0.313372
# ATR_Ratio         0.067669  0.072901  0.065439  0.070042  0.160301
# Next_Day_Return   0.033165  0.031213  0.031500  0.029685 -0.008998
# Target            0.057864  0.056668  0.056588  0.055680  0.011907
# Return_Lag1       0.056357  0.055083  0.059032  0.059575  0.121417
# Return_Lag2       0.056735  0.055287  0.057603  0.057705  0.047337
# Return_Lag3       0.055498  0.054493  0.055334  0.054821  0.048370
# RSI_Lag1          0.239168  0.237051  0.239229  0.238880  0.254551
# Day_of_Week      -0.000220  0.000250 -0.000284  0.000958  0.013101
#
#                   Volume_Ratio  Daily_Returns   MA_Week  MA_Month  MA_3Months  \
# Close                -0.002331       0.051441  0.998003  0.990080    0.972469
# High                  0.000969       0.042226  0.998799  0.991394    0.973288
# Low                  -0.008975       0.043595  0.997601  0.990039    0.973268
# Open                 -0.007347       0.034011  0.998077  0.990827    0.973438
# Volume                0.586696       0.296433  0.279135  0.272078    0.238743
# Volume_Ratio          1.000000       0.399263 -0.003208 -0.009086   -0.011818
# Daily_Returns         0.399263       1.000000  0.032195  0.027490    0.021963
# MA_Week              -0.003208       0.032195  1.000000  0.993965    0.976892
# MA_Month             -0.009086       0.027490  0.993965  1.000000    0.989391
# MA_3Months           -0.011818       0.021963  0.976892  0.989391    1.000000
# MA_Week_Ratio         0.370093       0.636142  0.085332  0.066694    0.053717
# MA_Month_Ratio        0.190779       0.327937  0.238573  0.183187    0.142722
# MA_3Months_Ratio      0.058886       0.210933  0.434699  0.386489    0.315104
# MACD                  0.034111       0.066835  0.696791  0.616754    0.544195
# MACD_Signal           0.030802       0.045209  0.745895  0.677399    0.595876
# volatility            0.027813       0.040013  0.141959  0.144718    0.109326
# RSI                   0.281520       0.454886  0.210046  0.167582    0.132581
# MACD_Histogram        0.019203       0.100916 -0.095480 -0.156324   -0.130285
# BB_Position           0.333852       0.439361  0.135378  0.102365    0.074060
# ATR_Ratio            -0.055774      -0.080037  0.076340  0.087661    0.063253
# Next_Day_Return      -0.033240       0.047452  0.031427  0.029290    0.023596
# Target               -0.022124       0.008621  0.054866  0.047437    0.036024
# Return_Lag1           0.182714       0.045443  0.038486  0.031396    0.024932
# Return_Lag2           0.042153      -0.016040  0.043222  0.033625    0.026776
# Return_Lag3           0.017941       0.007250  0.045228  0.033045    0.026456
# RSI_Lag1              0.143438       0.042051  0.219975  0.174350    0.137839
# Day_of_Week          -0.007042       0.002021 -0.000264  0.000828    0.001192
#
#                   ...  MACD_Histogram  BB_Position  ATR_Ratio  \
# Close             ...       -0.053742     0.155552   0.067669
# High              ...       -0.067614     0.151371   0.072901
# Low               ...       -0.050197     0.152478   0.065439
# Open              ...       -0.060015     0.149174   0.070042
# Volume            ...       -0.198594     0.313372   0.160301
# Volume_Ratio      ...        0.019203     0.333852  -0.055774
# Daily_Returns     ...        0.100916     0.439361  -0.080037
# MA_Week           ...       -0.095480     0.135378   0.076340
# MA_Month          ...       -0.156324     0.102365   0.087661
# MA_3Months        ...       -0.130285     0.074060   0.063253
# MA_Week_Ratio     ...        0.346208     0.755408  -0.146722
# MA_Month_Ratio    ...        0.374755     0.769465  -0.037049
# MA_3Months_Ratio  ...        0.165613     0.539881   0.079147
# MACD              ...        0.269945     0.318504   0.004286
# MACD_Signal       ...        0.040866     0.258203   0.056965
# volatility        ...       -0.156198     0.186643   0.826484
# RSI               ...        0.361329     0.942216  -0.053092
# MACD_Histogram    ...        1.000000     0.302212  -0.219504
# BB_Position       ...        0.302212     1.000000  -0.048963
# ATR_Ratio         ...       -0.219504    -0.048963   1.000000
# Next_Day_Return   ...       -0.001371     0.030801  -0.002353
# Target            ...        0.015281     0.041084   0.023911
# Return_Lag1       ...        0.161563     0.383987  -0.068152
# Return_Lag2       ...        0.188344     0.326215  -0.054182
# Return_Lag3       ...        0.201090     0.288364  -0.039890
# RSI_Lag1          ...        0.363231     0.830459  -0.027943
# Day_of_Week       ...       -0.003267    -0.014655  -0.001726
#
#                   Next_Day_Return    Target  Return_Lag1  Return_Lag2  \
# Close                    0.033165  0.057864     0.056357     0.056735
# High                     0.031213  0.056668     0.055083     0.055287
# Low                      0.031500  0.056588     0.059032     0.057603
# Open                     0.029685  0.055680     0.059575     0.057705
# Volume                  -0.008998  0.011907     0.121417     0.047337
# Volume_Ratio            -0.033240 -0.022124     0.182714     0.042153
# Daily_Returns            0.047452  0.008621     0.045443    -0.016040
# MA_Week                  0.031427  0.054866     0.038486     0.043222
# MA_Month                 0.029290  0.047437     0.031396     0.033625
# MA_3Months               0.023596  0.036024     0.024932     0.026776
# MA_Week_Ratio            0.034686  0.016552     0.552399     0.429922
# MA_Month_Ratio           0.046604  0.059078     0.327364     0.309072
# MA_3Months_Ratio         0.075620  0.084411     0.215052     0.209898
# MACD                     0.041031  0.095670     0.092133     0.109244
# MACD_Signal              0.042905  0.095620     0.056951     0.068299
# volatility              -0.005306  0.022627     0.049037     0.052621
# RSI                      0.040773  0.053225     0.408222     0.350365
# MACD_Histogram          -0.001371  0.015281     0.161563     0.188344
# BB_Position              0.030801  0.041084     0.383987     0.326215
# ATR_Ratio               -0.002353  0.023911    -0.068152    -0.054182
# Next_Day_Return          1.000000  0.675059    -0.016216     0.005403
# Target                   0.675059  1.000000    -0.001606     0.006591
# Return_Lag1             -0.016216 -0.001606     1.000000     0.047673
# Return_Lag2              0.005403  0.006591     0.047673     1.000000
# Return_Lag3              0.016345  0.006511    -0.015039     0.046980
# RSI_Lag1                 0.020268  0.055682     0.454396     0.408862
# Day_of_Week              0.045117  0.058107     0.000784    -0.014013
#
#                   Return_Lag3  RSI_Lag1  Day_of_Week
# Close                0.055498  0.239168    -0.000220
# High                 0.054493  0.237051     0.000250
# Low                  0.055334  0.239229    -0.000284
# Open                 0.054821  0.238880     0.000958
# Volume               0.048370  0.254551     0.013101
# Volume_Ratio         0.017941  0.143438    -0.007042
# Daily_Returns        0.007250  0.042051     0.002021
# MA_Week              0.045228  0.219975    -0.000264
# MA_Month             0.033045  0.174350     0.000828
# MA_3Months           0.026456  0.137839     0.001192
# MA_Week_Ratio        0.323938  0.614592     0.000832
# MA_Month_Ratio       0.292772  0.820318    -0.001874
# MA_3Months_Ratio     0.204408  0.639272     0.001866
# MACD                 0.120306  0.455731    -0.006396
# MACD_Signal          0.076729  0.386002    -0.005855
# volatility           0.059530  0.197696     0.011092
# RSI                  0.305745  0.881426    -0.013572
# MACD_Histogram       0.201090  0.363231    -0.003267
# BB_Position          0.288364  0.830459    -0.014655
# ATR_Ratio           -0.039890 -0.027943    -0.001726
# Next_Day_Return      0.016345  0.020268     0.045117
# Target               0.006511  0.055682     0.058107
# Return_Lag1         -0.015039  0.454396     0.000784
# Return_Lag2          0.046980  0.408862    -0.014013
# Return_Lag3          1.000000  0.349631     0.007569
# RSI_Lag1             0.349631  1.000000    -0.006375
# Day_of_Week          0.007569 -0.006375     1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# ### Droping redundant features .

# %%
df_TCS.drop(columns=['Next_Day_Return', 'MA_Week', 'MA_Month', 'MA_3Months', 'Volume', 'Date', 'Close', 'High', 'Low', 'Open'], inplace=True, errors='ignore')

# %%
# Check the Correlation between all the calculated values
corr_matrix = df_TCS.select_dtypes('number').corr()

plt.figure(figsize=(14,12))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Time Based Train Test Split

# %%
df_TCS = df_TCS.sort_index()
split_index = int(len(df_TCS)*0.8)

train = df_TCS.iloc[0:split_index]
test = df_TCS.iloc[split_index: len(df_TCS)]


print(f"Training ENDS: {train.index.max()}")
print(f"Testing Starts: {test.index.min()}")
# Out:
# Training ENDS: 2024-05-07 00:00:00
# Testing Starts: 2024-05-08 00:00:00

# %% [markdown]
# ### Feature Selection - Step 1: Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif

candidate_features = [c for c in train.columns if c != 'Target']
mi_scores = mutual_info_classif(train[candidate_features], train['Target'], random_state=42)

mi_ranking = pd.DataFrame({
    'Feature': candidate_features,
    'MI_Score': mi_scores
}).sort_values('MI_Score', ascending=False).reset_index(drop=True)

plt.figure(figsize=(10, 6))
plt.barh(mi_ranking['Feature'], mi_ranking['MI_Score'], color='steelblue')
plt.xlabel('Mutual Information Score')
plt.title('Feature Ranking by Mutual Information')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

print(mi_ranking.to_string(index=False))
# Out:
#          Feature  MI_Score
#    Daily_Returns  0.032584
#   MACD_Histogram  0.009874
#      Return_Lag2  0.003968
#   MA_Month_Ratio  0.002964
#         RSI_Lag1  0.002220
#        ATR_Ratio  0.002001
#      MACD_Signal  0.001808
#    MA_Week_Ratio  0.001145
#     Volume_Ratio  0.001059
#              RSI  0.000372
#       volatility  0.000000
# MA_3Months_Ratio  0.000000
#             MACD  0.000000
#      Return_Lag1  0.000000
#      BB_Position  0.000000
#      Return_Lag3  0.000000
#      Day_of_Week  0.000000

# %% [markdown]
# ### Feature Selection - Step 2: Random Forest Importance

# %%
from sklearn.ensemble import RandomForestClassifier

rf_selector = RandomForestClassifier(n_estimators=200, max_depth=12, random_state=42, n_jobs=-1)
rf_selector.fit(train[candidate_features], train['Target'])

rf_ranking = pd.DataFrame({
    'Feature': candidate_features,
    'RF_Importance': rf_selector.feature_importances_
}).sort_values('RF_Importance', ascending=False).reset_index(drop=True)

plt.figure(figsize=(10, 6))
plt.barh(rf_ranking['Feature'], rf_ranking['RF_Importance'], color='seagreen')
plt.xlabel('Random Forest Importance')
plt.title('Feature Ranking by Random Forest Importance')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

combined_ranking = mi_ranking.merge(rf_ranking, on='Feature')
combined_ranking['MI_Rank'] = combined_ranking['MI_Score'].rank(ascending=False).astype(int)
combined_ranking['RF_Rank'] = combined_ranking['RF_Importance'].rank(ascending=False).astype(int)
combined_ranking['Avg_Rank'] = (combined_ranking['MI_Rank'] + combined_ranking['RF_Rank']) / 2
combined_ranking = combined_ranking.sort_values('Avg_Rank').reset_index(drop=True)

print(combined_ranking[['Feature', 'MI_Score', 'RF_Importance', 'MI_Rank', 'RF_Rank', 'Avg_Rank']].to_string(index=False))
# Out:
#          Feature  MI_Score  RF_Importance  MI_Rank  RF_Rank  Avg_Rank
#   MACD_Histogram  0.009874       0.068227        2        1       1.5
#      Return_Lag2  0.003968       0.066929        3        3       3.0
#    Daily_Returns  0.032584       0.061066        1        6       3.5
#     Volume_Ratio  0.001059       0.067471        9        2       5.5
#    MA_Week_Ratio  0.001145       0.064557        8        4       6.0
#        ATR_Ratio  0.002001       0.060994        6        7       6.5
#         RSI_Lag1  0.002220       0.060966        5        8       6.5
#   MA_Month_Ratio  0.002964       0.054465        4       15       9.5
#      Return_Lag1  0.000000       0.062354       14        5       9.5
#      MACD_Signal  0.001808       0.056780        7       13      10.0
#              RSI  0.000372       0.057427       10       12      11.0
#      Return_Lag3  0.000000       0.060932       14        9      11.5
# MA_3Months_Ratio  0.000000       0.059353       14       10      12.0
#      BB_Position  0.000000       0.059163       14       11      12.5
#       volatility  0.000000       0.055504       14       14      14.0
#             MACD  0.000000       0.053973       14       16      15.0
#      Day_of_Week  0.000000       0.029839       14       17      15.5

# %% [markdown]
# ### Feature Selection - Step 3: RFECV with TimeSeriesSplit

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import TimeSeriesSplit

rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=100, max_depth=12, random_state=42, n_jobs=-1),
    step=1,
    cv=TimeSeriesSplit(n_splits=5),
    scoring='accuracy',
    min_features_to_select=3,
    n_jobs=-1
)
rfecv.fit(train[candidate_features], train['Target'])

selected_features = [f for f, keep in zip(candidate_features, rfecv.support_) if keep]

cv_scores = rfecv.cv_results_['mean_test_score']
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cv_scores) + 1), cv_scores, marker='o', color='darkorange')
plt.axvline(rfecv.n_features_, linestyle='--', color='red', label=f'Optimal: {rfecv.n_features_} features')
plt.xlabel('Number of Features')
plt.ylabel('Mean CV Accuracy')
plt.title('RFECV Feature Count vs Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f'Optimal number of features: {rfecv.n_features_}')
print(f'Best CV accuracy: {cv_scores.max():.4f}')
print(f'Selected features: {selected_features}')
# Out:
# Optimal number of features: 11
# Best CV accuracy: 0.5515
# Selected features: ['Volume_Ratio', 'MA_Week_Ratio', 'MA_3Months_Ratio', 'MACD', 'volatility', 'MACD_Histogram', 'BB_Position', 'ATR_Ratio', 'Return_Lag1', 'Return_Lag2', 'RSI_Lag1']

# %% [markdown]
# ### Feature Selection - Step 4: Verify New Feature Set Across All Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler

X_new = df_TCS[selected_features]
y_all = df_TCS['Target']

models_verify = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(random_state=42, max_depth=14),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=12, min_samples_split=6, random_state=42),
    'XGBoost': XGBClassifier(n_estimators=100, max_depth=6, learning_rate=0.1, random_state=42, eval_metric='logloss'),
    'SVC': SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42, probability=True)
}

tscv_new = TimeSeriesSplit(n_splits=5)
new_results = {name: {'accuracy': [], 'f1_class0': [], 'f1_class1': []} for name in models_verify}

for train_idx, test_idx in tscv_new.split(X_new):
    X_tr, X_te = X_new.iloc[train_idx], X_new.iloc[test_idx]
    y_tr, y_te = y_all.iloc[train_idx], y_all.iloc[test_idx]

    scaler_v = StandardScaler()
    X_tr_s = scaler_v.fit_transform(X_tr)
    X_te_s = scaler_v.transform(X_te)

    for name, model in models_verify.items():
        if name == 'Random Forest':
            model.fit(X_tr, y_tr)
            y_p = model.predict(X_te)
        else:
            model.fit(X_tr_s, y_tr)
            y_p = model.predict(X_te_s)
        new_results[name]['accuracy'].append(accuracy_score(y_te, y_p))
        new_results[name]['f1_class0'].append(f1_score(y_te, y_p, pos_label=0.0))
        new_results[name]['f1_class1'].append(f1_score(y_te, y_p, pos_label=1.0))

baseline_acc = {
    'Logistic Regression': 0.5169,
    'Decision Tree': 0.5110,
    'Random Forest': 0.5192,
    'XGBoost': 0.4994,
    'SVC': 0.5186
}

comparison = pd.DataFrame({
    'Model': list(new_results.keys()),
    'Baseline (4 feat)': [baseline_acc[m] for m in new_results],
    'New (15 feat)': [np.mean(new_results[m]['accuracy']) for m in new_results],
    'F1 (Down)': [np.mean(new_results[m]['f1_class0']) for m in new_results],
    'F1 (Up)': [np.mean(new_results[m]['f1_class1']) for m in new_results],
})
comparison['Improvement'] = comparison['New (15 feat)'] - comparison['Baseline (4 feat)']
comparison = comparison.sort_values('New (15 feat)', ascending=False).reset_index(drop=True)
print(comparison.to_string(index=False))
# Out:
#               Model  Baseline (4 feat)  New (15 feat)  F1 (Down)  F1 (Up)  Improvement
#       Random Forest             0.5192       0.527763   0.605649 0.393666     0.008563
#                 SVC             0.5186       0.523450   0.668677 0.136693     0.004850
#             XGBoost             0.4994       0.515903   0.577062 0.421301     0.016503
#       Decision Tree             0.5110       0.515364   0.545551 0.472413     0.004364
# Logistic Regression             0.5169       0.511051   0.654754 0.143621    -0.005849

# %%
y_train = train['Target']
y_test = test['Target']



features = ['MACD_Signal', 'Return_Lag1', 'Return_Lag3', 'ATR_Ratio', 'RSI_Lag1', 'RSI', 'MACD_Histogram']
# features = ['Return_Lag1', 'MA_3Months_Ratio', 'MA_Week_Ratio', 'volatility', 'Return_Lag3']

X_train = train[features]
X_test = test[features]

# %%
df_TCS[features + ['Target']].corr()
# Out:
#                 MACD_Signal  Return_Lag1  Return_Lag3  ATR_Ratio  RSI_Lag1  \
# MACD_Signal        1.000000     0.056951     0.076729   0.056965  0.386002
# Return_Lag1        0.056951     1.000000    -0.015039  -0.068152  0.454396
# Return_Lag3        0.076729    -0.015039     1.000000  -0.039890  0.349631
# ATR_Ratio          0.056965    -0.068152    -0.039890   1.000000 -0.027943
# RSI_Lag1           0.386002     0.454396     0.349631  -0.027943  1.000000
# RSI                0.363107     0.408222     0.305745  -0.053092  0.881426
# MACD_Histogram     0.040866     0.161563     0.201090  -0.219504  0.363231
# Target             0.095620    -0.001606     0.006511   0.023911  0.055682
#
#                      RSI  MACD_Histogram    Target
# MACD_Signal     0.363107        0.040866  0.095620
# Return_Lag1     0.408222        0.161563 -0.001606
# Return_Lag3     0.305745        0.201090  0.006511
# ATR_Ratio      -0.053092       -0.219504  0.023911
# RSI_Lag1        0.881426        0.363231  0.055682
# RSI             1.000000        0.361329  0.053225
# MACD_Histogram  0.361329        1.000000  0.015281
# Target          0.053225        0.015281  1.000000

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_trained_Scaled = scaler.fit_transform(X_train)
X_test_Scaled = scaler.transform(X_test)

# %%
X_test_Scaled
# Out:
# array([[-1.64351013, -1.25170675, -0.26835454, ..., -1.72625019,
#         -0.88366493, -4.45131774],
#        [-1.87841218,  1.49615937, -1.37411384, ..., -0.88541538,
#         -0.63371337, -3.50938529],
#        [-2.0881841 ,  0.44178368, -1.25771795, ..., -0.63503392,
#         -0.94590927, -3.13304317],
#        ...,
#        [ 0.20770853, -0.24149832, -0.71114064, ...,  0.00601717,
#         -0.27134952, -0.33588073],
#        [ 0.10574168, -0.49917892,  0.79193018, ..., -0.27204683,
#         -0.46092525, -1.5185834 ],
#        [-0.03092459, -0.36970945, -0.24354032, ..., -0.46194862,
#         -0.39528572, -2.03823257]], shape=(447, 7))

# %% [markdown]
# ### Training Models

# %%
# Training A Logistic Regression Model
from sklearn.linear_model import LogisticRegression


model_Logistic_regression = LogisticRegression()

model_Logistic_regression.fit(X_trained_Scaled, y_train)

model_prediction_learning = model_Logistic_regression.predict(X_test_Scaled)

# %%
from sklearn.metrics import accuracy_score

prediction_Logistic_regression = accuracy_score(y_test, model_prediction_learning)
print(prediction_Logistic_regression)
# Out:
# 0.5883668903803132

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, model_prediction_learning)
print(cm)
# Out:
# [[161  66]
#  [118 102]]

# %%
from sklearn.metrics import classification_report

cr = classification_report(y_test, model_prediction_learning)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.71      0.64       227
#          1.0       0.61      0.46      0.53       220
#
#     accuracy                           0.59       447
#    macro avg       0.59      0.59      0.58       447
# weighted avg       0.59      0.59      0.58       447

# %%
'''
Despite a balanced dataset, the model exhibited biased 
predictions due to the weak and noisy nature of stock market signals. 
This suggests that simple linear models are insufficient for capturing 
market dynamics.
'''
# Out:
# '\nDespite a balanced dataset, the model exhibited biased \npredictions due to the weak and noisy nature of stock market signals. \nThis suggests that simple linear models are insufficient for capturing \nmarket dynamics.\n'

# %% [markdown]
# ### Using the Decision Trees Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

Decision_Tree_Model = DecisionTreeClassifier(random_state=42, max_depth=14)

# %%
train_accuracies = []
test_accuracies = []

# The range of depths we want to test (from 1 to 15)
depth_range = range(1, 16)

# Loop through each depth
for depth in depth_range:
    # 1. Build and train the tree
    tree = DecisionTreeClassifier(max_depth=depth, random_state=42)
    tree.fit(X_trained_Scaled, y_train)
    
    # 2. Check accuracy on Training Data
    train_pred = tree.predict(X_trained_Scaled)
    train_acc = accuracy_score(y_train, train_pred)
    train_accuracies.append(train_acc)
    
    # 3. Check accuracy on Testing Data
    test_pred = tree.predict(X_test_Scaled)
    test_acc = accuracy_score(y_test, test_pred)
    test_accuracies.append(test_acc)

# --- Plotting the Results ---
plt.figure(figsize=(10, 6))
plt.plot(depth_range, train_accuracies, label='Training Accuracy', marker='o', color='blue')
plt.plot(depth_range, test_accuracies, label='Testing Accuracy', marker='o', color='red')

plt.title('Decision Tree: Max Depth vs. Accuracy')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy')
plt.xticks(depth_range)
plt.legend()
plt.grid(True)
plt.show()

# %%
Decision_Tree_Model.fit(X_trained_Scaled, y_train)
# Out:
# DecisionTreeClassifier(max_depth=14, random_state=42)

# %%
Decision_Tree_Predictions = Decision_Tree_Model.predict(X_test_Scaled)

# %%
Decision_Tree_Accuracy = accuracy_score(y_test, Decision_Tree_Predictions)
print(Decision_Tree_Accuracy)
# Out:
# 0.465324384787472

# %%
DT_cm = confusion_matrix(y_test, Decision_Tree_Predictions)
print(DT_cm)
# Out:
# [[116 111]
#  [128  92]]

# %%
DT_cr = classification_report(y_test, Decision_Tree_Predictions)
print(DT_cr)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.51      0.49       227
#          1.0       0.45      0.42      0.43       220
#
#     accuracy                           0.47       447
#    macro avg       0.46      0.46      0.46       447
# weighted avg       0.46      0.47      0.46       447

# %%
# The previous model predicted model would go up 441 times, catching almost all the upward trends but failing miserably at identifying downward trends .

# %%
## The Decision Tree Completely Fixed this blind spot . BY chaining those IF/THEN rules togeather, It successfully identified 163 True Down days (True Negatives). That is an improvement of 240% in protecting capital from bad trades.

# %% [markdown]
# ### Reciever Operating Characteristic Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

logistic_probs = model_Logistic_regression.predict_proba(X_test_Scaled)[:, 1]
decision_tree_probs = Decision_Tree_Model.predict_proba(X_test_Scaled)[:, 1]

logistic_fpr, logistic_tpr, _ = roc_curve(y_test, logistic_probs)
decision_tree_fpr, decision_tree_tpr, _ = roc_curve(y_test, decision_tree_probs)

logistic_auc = roc_auc_score(y_test, logistic_probs)
decision_tree_auc = roc_auc_score(y_test, decision_tree_probs)

plt.figure(figsize=(10, 6))
plt.plot(logistic_fpr, logistic_tpr, label=f'Logistic Regression (AUC = {logistic_auc:.3f})', linewidth=2)
plt.plot(decision_tree_fpr, decision_tree_tpr, label=f'Decision Tree (AUC = {decision_tree_auc:.3f})', linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend()
plt.grid(True)
plt.show()

print(f"Logistic Regression AUC: {logistic_auc:.4f}")
print(f"Decision Tree AUC: {decision_tree_auc:.4f}")
# Out:
# Logistic Regression AUC: 0.5648
# Decision Tree AUC: 0.4543

# %% [markdown]
# ### Implementing Random Forest

# %% [markdown]
# #### Many decision trees + combine their predictions , Many decision trees + combine their predictions

# %%
from sklearn.ensemble import RandomForestClassifier


model_rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=12,
    min_samples_split=6,
    random_state=42
)

model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=12, min_samples_split=6, random_state=42)

# %%
y_pred_rf = model_rf.predict(X_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy : ", accuracy_rf)
# Out:
# Random Forest Accuracy :  0.47874720357941836

# %%
from sklearn.metrics import confusion_matrix

cm_rf = confusion_matrix(y_test, y_pred_rf)
print(cm_rf)
# Out:
# [[ 82 145]
#  [ 88 132]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.36      0.41       227
#          1.0       0.48      0.60      0.53       220
#
#     accuracy                           0.48       447
#    macro avg       0.48      0.48      0.47       447
# weighted avg       0.48      0.48      0.47       447

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model_rf.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(feature_importance)
# Out:
#           Feature  Importance
# 6  MACD_Histogram    0.153860
# 4        RSI_Lag1    0.150885
# 5             RSI    0.146640
# 0     MACD_Signal    0.144444
# 3       ATR_Ratio    0.139550
# 1     Return_Lag1    0.135339
# 2     Return_Lag3    0.129282

# %% [markdown]
# ### Implementing XGBoost

# %%
from xgboost import XGBClassifier

model_xgb = XGBClassifier(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    random_state=42,
    eval_metric='logloss'
)

model_xgb.fit(X_trained_Scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_xgb = model_xgb.predict(X_test_Scaled)

accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print("XGBoost Accuracy:", accuracy_xgb)
# Out:
# XGBoost Accuracy: 0.4519015659955257

# %%
cm_xgb = confusion_matrix(y_test, y_pred_xgb)
print(cm_xgb)
# Out:
# [[ 92 135]
#  [110 110]]

# %%
cr_xgb = classification_report(y_test, y_pred_xgb)
print(cr_xgb)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.41      0.43       227
#          1.0       0.45      0.50      0.47       220
#
#     accuracy                           0.45       447
#    macro avg       0.45      0.45      0.45       447
# weighted avg       0.45      0.45      0.45       447

# %% [markdown]
# ### Implementing Support Vector Classifier (SVC)

# %%
from sklearn.svm import SVC

model_svc = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42, probability=True)

model_svc.fit(X_trained_Scaled, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
y_pred_svc = model_svc.predict(X_test_Scaled)

accuracy_svc = accuracy_score(y_test, y_pred_svc)
print("SVC Accuracy:", accuracy_svc)
# Out:
# SVC Accuracy: 0.5503355704697986

# %%
cm_svc = confusion_matrix(y_test, y_pred_svc)
print(cm_svc)
# Out:
# [[173  54]
#  [147  73]]

# %%
cr_svc = classification_report(y_test, y_pred_svc)
print(cr_svc)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.76      0.63       227
#          1.0       0.57      0.33      0.42       220
#
#     accuracy                           0.55       447
#    macro avg       0.56      0.55      0.53       447
# weighted avg       0.56      0.55      0.53       447

# %% [markdown]
# ### TimeSeriesSplit Cross-Validation

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

features = ['Return_Lag1', 'Volume_Ratio', 'RSI', 'RSI_Lag1']
X = df_TCS[features]
y = df_TCS['Target']

models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(random_state=42, max_depth=14),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=12, min_samples_split=6, random_state=42),
    'XGBoost': XGBClassifier(n_estimators=100, max_depth=6, learning_rate=0.1, random_state=42, eval_metric='logloss'),
    'SVC': SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42, probability=True)
}

tscv = TimeSeriesSplit(n_splits=5)

results = {name: {'accuracy': [], 'f1_class0': [], 'f1_class1': []} for name in models}

for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    X_train_fold, X_test_fold = X.iloc[train_idx], X.iloc[test_idx]
    y_train_fold, y_test_fold = y.iloc[train_idx], y.iloc[test_idx]

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_fold)
    X_test_scaled = scaler.transform(X_test_fold)

    for name, model in models.items():
        if name == 'Random Forest':
            model.fit(X_train_fold, y_train_fold)
            y_pred = model.predict(X_test_fold)
        else:
            model.fit(X_train_scaled, y_train_fold)
            y_pred = model.predict(X_test_scaled)

        results[name]['accuracy'].append(accuracy_score(y_test_fold, y_pred))
        results[name]['f1_class0'].append(f1_score(y_test_fold, y_pred, pos_label=0.0))
        results[name]['f1_class1'].append(f1_score(y_test_fold, y_pred, pos_label=1.0))

summary = pd.DataFrame({
    'Model': list(results.keys()),
    'Mean Accuracy': [np.mean(results[m]['accuracy']) for m in results],
    'Std Accuracy': [np.std(results[m]['accuracy']) for m in results],
    'Mean F1 (Down)': [np.mean(results[m]['f1_class0']) for m in results],
    'Mean F1 (Up)': [np.mean(results[m]['f1_class1']) for m in results],
})

summary = summary.sort_values('Mean Accuracy', ascending=False).reset_index(drop=True)
print(summary.to_string(index=False))
# Out:
#               Model  Mean Accuracy  Std Accuracy  Mean F1 (Down)  Mean F1 (Up)
#       Random Forest       0.529380      0.031136        0.585968      0.448066
#                 SVC       0.521833      0.022973        0.651858      0.194963
# Logistic Regression       0.518059      0.020127        0.675499      0.048438
#       Decision Tree       0.515364      0.026596        0.544444      0.474235
#             XGBoost       0.514825      0.022935        0.569850      0.436991
